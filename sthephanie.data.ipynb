# %%
import pandas as pd
profesores={
    "profesores": ["jose", "juan", "pablo", "derek","sebastian", "sharon","emely","armenia", "paula", "mishel"],
    "trabajadores": ["steven", "eduardo", "yamileth", "yasuri","judit", "sofia","silveria","michi", "coryna", "lesbia"],
    "apellidos": ["ibañez", "diaz", "reynosa", "muñoz", "gil", "suarez","santos", "lemus", "lopez", "quiñones"],
     "curso": ["lenguaje", "matematicas", "etica","sociales","computacion","drl","fisica","estadistica", "seminario","programacion"],
     "edad": ["25", "30", "15", "45","36","47","13","26", "25","18"],

}
registro1 = pd.DataFrame(profesores)
print(registro1)
# Out:
#   profesores trabajadores apellidos         curso edad
# 0       jose       steven    ibañez      lenguaje   25
# 1       juan      eduardo      diaz   matematicas   30
# 2      pablo     yamileth   reynosa         etica   15
# 3      derek       yasuri     muñoz      sociales   45
# 4  sebastian        judit       gil   computacion   36
# 5     sharon        sofia    suarez           drl   47
# 6      emely     silveria    santos        fisica   13
# 7    armenia        michi     lemus   estadistica   26
# 8      paula       coryna     lopez     seminario   25
# 9     mishel       lesbia  quiñones  programacion   18

# %%
import pandas as pd
trabajadores={
    "ID": ["001", "587", "256", "123","312", "338","882","698", "784", "475"],
    "nombre": ["steven", "eduardo", "yamileth", "yasuri","judit", "sofia","silveria","michi", "coryna", "lesbia"],
    "apellidos": ["ibañez", "diaz", "reynosa", "muñoz", "gil", "suarez","santos", "lemus", "lopez", "quiñones"],
     "puesto": ["gerente", "sungerente", "empleado","esclavo","jefe","empleado","subempleado","director", "dueño","jefe"],
     "edad": ["25", "30", "15", "45","36","47","13","26", "25","18"],

}
registro2 = pd.DataFrame(trabajadores)
print(registro2)
# Out:
#     ID    nombre apellidos       puesto edad
# 0  001    steven    ibañez      gerente   25
# 1  587   eduardo      diaz   sungerente   30
# 2  256  yamileth   reynosa     empleado   15
# 3  123    yasuri     muñoz      esclavo   45
# 4  312     judit       gil         jefe   36
# 5  338     sofia    suarez     empleado   47
# 6  882  silveria    santos  subempleado   13
# 7  698     michi     lemus     director   26
# 8  784    coryna     lopez        dueño   25
# 9  475    lesbia  quiñones         jefe   18
